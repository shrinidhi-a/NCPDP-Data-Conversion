# %%
#Connect MongoDb and snowflake to load the data
import pandas as pd
from pymongo import MongoClient
import snowflake.connector

try:
    # Step 1: Connect to MongoDB
    mongo_client = MongoClient("mongodb://localhost:27017")  # Update if using Atlas
    db = mongo_client["NewDB"]
    collection = db["healthcare"]

    # Step 2: Load data from MongoDB
    documents = list(collection.find())
    if not documents:
        raise ValueError("No documents found in MongoDB collection.")

    # Step 3: Convert to DataFrame
    df = pd.DataFrame(documents)

    # Step 4: Drop MongoDB internal _id field
    if '_id' in df.columns:
        df = df.drop(columns=['_id'])

    # Step 5: Convert date columns to string
    for col in df.select_dtypes(include=['datetime', 'datetimetz', 'date']).columns:
        df[col] = df[col].astype(str)

    # Step 6: Connect to Snowflake
    conn = snowflake.connector.connect(
        user='Fizan',
        password='Tietoevry12345',
        account='bu51577.central-india.azure',
        warehouse='SNOWFLAKE_LEARNING_WH',
        database='SNOWFLAKE_LEARNING_DB',
        schema='MTM_ANALYTICS',
        role='ACCOUNTADMIN'
    )
    cursor = conn.cursor()

    # Step 7: Prepare Insert Query
    table_name = 'MTM_RECORDS'
    columns = list(df.columns)
    insert_query = f"""
        INSERT INTO {table_name} ({', '.join(columns)})
        VALUES ({', '.join(['%s'] * len(columns))})
    """

    # Step 8: Insert Data
    for _, row in df.iterrows():
        values = tuple(row.fillna("").values.tolist())
        cursor.execute(insert_query, values)

    conn.commit()
    print("✅ JSON data from MongoDB loaded into Snowflake.")

except Exception as e:
    print(f"❌ Error: {e}")

finally:
    try:
        cursor.close()
        conn.close()
    except:
        pass
# Out:
# ❌ Error: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 683584a7dc3ce87067aeedd4, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>

# %%
#To get the MTM Data to display at the front end
import snowflake.connector
import pandas as pd
import json
import datetime

try:
    # Step 1: Connect to Snowflake
    conn = snowflake.connector.connect(
        user='Fizan',
        password='Tietoevry12345',
        account='bu51577.central-india.azure',
        warehouse='SNOWFLAKE_LEARNING_WH',
        database='SNOWFLAKE_LEARNING_DB',
        schema='MTM_ANALYTICS',
        role='ACCOUNTADMIN'
    )
    cursor = conn.cursor()

    # Step 2: Fetch all data from the table
    query = "SELECT * FROM MTM_RECORDS"
    cursor.execute(query)

    # Step 3: Get column names
    columns = [col[0] for col in cursor.description]

    # Step 4: Load rows into DataFrame
    rows = cursor.fetchall()
    df = pd.DataFrame(rows, columns=columns)

    # Step 5: Convert all datetime/date columns to string
    for col in df.columns:
        if pd.api.types.is_datetime64_any_dtype(df[col]):
            df[col] = df[col].astype(str)
        else:
            if df[col].dtype == 'object':
                if df[col].dropna().apply(lambda x: isinstance(x, (datetime.date, datetime.datetime))).all():
                    df[col] = df[col].astype(str)

    # Step 6: Convert to JSON
    json_data = df.to_dict(orient='records')

    # Step 7: Save to file
    with open('mtm_data_export.json', 'w', encoding='utf-8') as f:
        json.dump(json_data, f, ensure_ascii=False, indent=4)

    print("✅ Data exported to mtm_data_export.json successfully.")

except Exception as e:
    print(f"❌ Error: {e}")

finally:
    try:
        cursor.close()
        conn.close()
    except:
        pass
# Out:
# ✅ Data exported to mtm_data_export.json successfully.

# %%
#Script to connect python and Snowflake
import snowflake.connector
import pandas as pd

try:
    # Connect to Snowflake
    conn = snowflake.connector.connect(
        user='Fizan',
        password='Tietoevry12345',
        account='bu51577.central-india.azure',
        warehouse='SNOWFLAKE_LEARNING_WH',
        database='SNOWFLAKE_LEARNING_DB',
        schema='MTM_ANALYTICS',
        role='ACCOUNTADMIN'
    )
    cursor = conn.cursor()

    # Load data
    final_df = pd.read_csv("MTMData.csv")

    # Rename columns to match Snowflake table exactly
    final_df.rename(columns={
        "Record Type": "RECORD_TYPE",
        "Transaction ID": "TRANSACTION_ID",
        "Date": "DATE",
        "Pharmacy NCPDP ID": "PHARMACY_NCPDP_ID",
        "Pharmacist NPI": "PHARMACIST_NPI",
        "Patient ID": "PATIENT_ID",
        "Patient Name": "PATIENT_NAME",
        "DOB": "DOB",
        "Gender": "GENDER",
        "Payer ID": "PAYER_ID",
        "Plan Name": "PLAN_NAME",
        "Intervention Type": "INTERVENTION_TYPE",
        "MTM Service Code": "MTM_SERVICE_CODE",
        "Start Date": "START_DATE",
        "End Date": "END_DATE",
        "Outcome": "OUTCOME",
        "Recommendations": "RECOMMENDATIONS",
        "Prescriber Contacted": "PRESCRIBER_CONTACTED",
        "Prescriber NPI": "PRESCRIBER_NPI",
        "Prescriber Response": "PRESCRIBER_RESPONSE",
        "Follow-up Date": "FOLLOW_UP_DATE",
        "Notes": "NOTES"
    }, inplace=True)

    # Ensure all required columns exist
    expected_columns = [
        'RECORD_TYPE', 'TRANSACTION_ID', 'DATE', 'PHARMACY_NCPDP_ID', 'PHARMACIST_NPI',
        'PATIENT_ID', 'PATIENT_NAME', 'DOB', 'GENDER', 'PAYER_ID', 'PLAN_NAME',
        'INTERVENTION_TYPE', 'MTM_SERVICE_CODE', 'START_DATE', 'END_DATE',
        'OUTCOME', 'RECOMMENDATIONS', 'PRESCRIBER_CONTACTED', 'PRESCRIBER_NPI',
        'PRESCRIBER_RESPONSE', 'FOLLOW_UP_DATE', 'NOTES'
    ]
    missing_cols = [col for col in expected_columns if col not in final_df.columns]
    if missing_cols:
        raise ValueError(f"Missing columns in CSV: {missing_cols}")

    # Insert rows
    insert_query = f"""
        INSERT INTO MTM_RECORDS ({', '.join(expected_columns)})
        VALUES ({', '.join(['%s'] * len(expected_columns))})
    """
    for _, row in final_df.iterrows():
        values = tuple(row.fillna("").values.tolist())
        cursor.execute(insert_query, values)

    conn.commit()
    print("✅ Data uploaded successfully to MTM_RECORDS table.")


except Exception as e:
    print(f"❌ Error: {e}")

finally:
    try:
        cursor.close()
        conn.close()
    except:
        pass
# Out:
# ✅ Data uploaded successfully to MTM_RECORDS table.

# %%
import snowflake.connector

try:
    # Connect to Snowflake
    conn = snowflake.connector.connect(
        user='Fizan',
        password='',
        account='bu51577.central-india.azure',  # Include region for your Snowflake account
        warehouse='SNOWFLAKE_LEARNING_WH',
        database='SNOWFLAKE_LEARNING_DB',
        schema='MTM_ANALYTICS',
        role='ACCOUNTADMIN'
    )

    cursor = conn.cursor()
    cursor.execute("SELECT CURRENT_USER()")
    user = cursor.fetchone()
    print(f"Connected to Snowflake as user: {user[0]}")

    cursor.close()
    conn.close()

except Exception as e:
    print("Failed to connect to Snowflake:", e)
# Out:
# Connected to Snowflake as user: FIZAN

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.8 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 15.0 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.13.0

# %%
# !pip install snowflake-connector-python pandas
# Out:
# Collecting snowflake-connector-python
#   Downloading snowflake_connector_python-3.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting asn1crypto<2.0.0,>0.24.0 (from snowflake-connector-python)
#   Downloading asn1crypto-1.5.1-py2.py3-none-any.whl.metadata (13 kB)
# Collecting boto3>=1.24 (from snowflake-connector-python)
#   Downloading boto3-1.38.23-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore>=1.24 (from snowflake-connector-python)
#   Downloading botocore-1.38.23-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (1.17.1)
# Requirement already satisfied: cryptography>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (43.0.3)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (24.2.1)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (2.10.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (2025.2)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (24.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (2025.4.26)
# Requirement already satisfied: typing_extensions<5,>=4.3 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (4.13.2)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (3.18.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from snowflake-connector-python) (4.3.8)
# Collecting tomlkit (from snowflake-connector-python)
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.24->snowflake-connector-python)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3>=1.24->snowflake-connector-python)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore>=1.24->snowflake-connector-python) (2.4.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading snowflake_connector_python-3.15.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 34.1 MB/s eta 0:00:00
# Downloading asn1crypto-1.5.1-py2.py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 7.3 MB/s eta 0:00:00
# Downloading boto3-1.38.23-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 10.6 MB/s eta 0:00:00
# Downloading botocore-1.38.23-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 105.0 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: asn1crypto, tomlkit, jmespath, botocore, s3transfer, boto3, snowflake-connector-python
# Successfully installed asn1crypto-1.5.1 boto3-1.38.23 botocore-1.38.23 jmespath-1.0.1 s3transfer-0.13.0 snowflake-connector-python-3.15.0 tomlkit-0.13.2

# %%
import csv
import json
import os

def csv_to_json_mtm(csv_dir, json_filepath, limit=50):
    patient_data = {}

    # Base structure
    csv_files = [
        'patients.csv', 'careplans.csv', 'providers.csv', 'allergies.csv', 'procedures.csv',
        'observations.csv', 'medications.csv', 'payers.csv', 'supplies.csv', 'conditions.csv',
        'devices.csv', 'encounters.csv', 'imaging_studies.csv', 'immunizations.csv',
        'organizations.csv', 'payer_transitions.csv'
    ]

    # Step 1: Load patients.csv
    try:
        with open(os.path.join(csv_dir, 'patients.csv'), 'r', encoding='utf-8') as file:
            for row in csv.DictReader(file):
                pid = row.get('Id')
                if pid:
                    patient_data[pid] = {
                        'patient_details': row,
                        'mtm': {
                            'interventions': [],
                            'medications': [],
                            'clinical_issues': [],
                            'outcomes': [],
                            'follow_up_actions': [],
                            'billing': []
                        },
                        'other_data': {}
                    }
    except Exception as e:
        print(f"Error reading patients.csv: {e}")
        return

    # Step 2: Process other CSVs
    for filename in csv_files[1:]:
        path = os.path.join(csv_dir, filename)
        try:
            with open(path, 'r', encoding='utf-8') as file:
                reader = csv.DictReader(file)
                count = 0
                for row in reader:
                    if count >= limit:
                        break
                    pid = row.get('PATIENT')
                    if not pid or pid not in patient_data:
                        continue

                    # MTM Mappings
                    mtm = patient_data[pid]['mtm']
                    if filename in ['careplans.csv', 'procedures.csv']:
                        mtm['interventions'].append(row)
                    elif filename == 'medications.csv':
                        mtm['medications'].append(row)
                    elif filename in ['conditions.csv', 'observations.csv']:
                        mtm['clinical_issues'].append(row)
                    elif filename in ['observations.csv', 'encounters.csv']:
                        mtm['outcomes'].append(row)
                    elif filename in ['careplans.csv', 'encounters.csv']:
                        mtm['follow_up_actions'].append(row)
                    elif filename in ['payers.csv', 'payer_transitions.csv']:
                        mtm['billing'].append(row)
                    else:
                        key = filename.replace('.csv', '')
                        if key not in patient_data[pid]['other_data']:
                            patient_data[pid]['other_data'][key] = []
                        patient_data[pid]['other_data'][key].append(row)

                    count += 1
        except FileNotFoundError:
            print(f"File not found: {filename}")
        except Exception as e:
            print(f"Error reading {filename}: {e}")

    # Step 3: Write to JSON
    try:
        with open(json_filepath, 'w', encoding='utf-8') as out:
            json.dump(patient_data, out, indent=4)
        print(f"✅ MTM-formatted JSON saved to {json_filepath}")
    except Exception as e:
        print(f"Error writing JSON: {e}")

# Usage
csv_to_json_mtm('drive/MyDrive/NCPDP/csv', 'mtm_patient_output.json')
# Out:
# ✅ MTM-formatted JSON saved to mtm_patient_output.json

# %%
import csv
import json
import os

def csv_to_json_nested(csv_dir, json_filepath, limit=50):
    files = [
        'patients.csv', 'careplans.csv', 'providers.csv', 'allergies.csv',
        'procedures.csv', 'observations.csv', 'medications.csv', 'payers.csv',
        'supplies.csv', 'conditions.csv', 'devices.csv', 'encounters.csv',
        'imaging_studies.csv', 'immunizations.csv', 'organizations.csv',
        'payer_transitions.csv'
    ]

    patient_data = {}

    # Step 1: Load patients.csv
    try:
        with open(os.path.join(csv_dir, 'patients.csv'), 'r', encoding='utf-8') as f:
            for row in csv.DictReader(f):
                pid = row.get('Id')
                if pid:
                    patient_data[pid] = {'patient_details': row}
    except Exception as e:
        print(f"Error loading patients.csv: {e}")
        return

    # Step 2: Load all other files and group by PATIENT ID
    for file in files[1:]:
        path = os.path.join(csv_dir, file)
        key = file.replace('.csv', '')

        try:
            with open(path, 'r', encoding='utf-8') as f:
                for i, row in enumerate(csv.DictReader(f)):
                    if i >= limit:
                        break
                    pid = row.get('PATIENT')
                    if pid in patient_data:
                        patient_data[pid].setdefault(key, []).append(row)
        except FileNotFoundError:
            print(f"Missing file: {file}, skipping...")
        except Exception as e:
            print(f"Error reading {file}: {e}")

    # Step 3: Save to JSON
    try:
        with open(json_filepath, 'w', encoding='utf-8') as f:
            json.dump(patient_data, f, indent=4)
        print(f"✅ Data saved to {json_filepath}")
    except Exception as e:
        print(f"Error writing JSON: {e}")

# Example usage
csv_dir = 'drive/MyDrive/NCPDP/csv'
json_filepath = 'sampleOutput.json'
csv_to_json_nested(csv_dir, json_filepath)
# Out:
# ✅ Data saved to sampleOutput.json

# %%
import csv
import json
import os

def csv_to_json_nested(csv_dir, json_filepath, limit=50):
    patient_data = {}  # Dictionary to store patient data

    csv_files = ['patients.csv', 'careplans.csv',
                 'providers.csv', 'allergies.csv',
                 'procedures.csv', 'observations.csv',
                 'medications.csv','payers.csv',
                 'supplies.csv','conditions.csv',
                 'devices.csv','encounters.csv',
                 'imaging_studies.csv','immunizations.csv',
                 'organizations.csv','payer_transitions.csv']  # Add your CSV file names here

    # Process patients.csv first to create the root structure
    patients_filepath = os.path.join(csv_dir, 'patients.csv')
    try:
        with open(patients_filepath, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                patient_id = row.get('Id')  # Get patient ID from 'id' column
                if patient_id:
                    patient_data[patient_id] = {'patient_details': row}  # Store patient details as root
    except FileNotFoundError:
        print(f"File not found: {patients_filepath}")
        return
    except Exception as e:
        print(f"An error occurred while reading {patients_filepath}: {e}")
        return

    # Process other CSV files and nest data under patient IDs
    for filename in csv_files[1:]:  # Skip patients.csv (already processed)
        csv_filepath = os.path.join(csv_dir, filename)
        print(f"Checking file: {csv_filepath}")

        try:
            with open(csv_filepath, 'r', encoding='utf-8') as csvfile:
                reader = csv.DictReader(csvfile)
                print(f"Reading file: {csv_filepath}")
                count = 0
                for row in reader:
                    if count < limit:
                        patient_id = row.get('PATIENT')  # Get patient ID from 'PATIENT' column
                        if patient_id and patient_id in patient_data:
                            # Use filename as key for nested data
                            if filename[:-4] not in patient_data[patient_id]:
                                patient_data[patient_id][filename[:-4]] = []
                            patient_data[patient_id][filename[:-4]].append(row)
                            count += 1
                            print(f"Added data for patient {patient_id} from {filename}")
                    else:
                        break
        except FileNotFoundError:
            print(f"File not found: {csv_filepath}")
            continue
        except Exception as e:
            print(f"An error occurred while reading {csv_filepath}: {e}")
            return

    print(f"Total patients: {len(patient_data)}")

    try:
        with open(json_filepath, 'w', encoding='utf-8') as jsonfile:
            json.dump(patient_data, jsonfile, indent=4)
        print(f"Successfully converted data from multiple CSV files to nested JSON.")
    except Exception as e:
        print(f"An error occurred while writing to JSON file: {e}")

# Example usage:
csv_dir = 'drive/MyDrive/NCPDP/csv'  # Directory containing CSV files
json_filepath = 'sampleOutput.json'
csv_to_json_nested(csv_dir, json_filepath)
# Out:
# Checking file: drive/MyDrive/NCPDP/csv/careplans.csv
# Reading file: drive/MyDrive/NCPDP/csv/careplans.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from careplans.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from careplans.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from careplans.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from careplans.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from careplans.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from careplans.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from careplans.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from careplans.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from careplans.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from careplans.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from careplans.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from careplans.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from careplans.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from careplans.csv
# Added data for patient 4fdafa07-e5cb-9b2a-55c6-50902c49ccfb from careplans.csv
# Added data for patient 4fdafa07-e5cb-9b2a-55c6-50902c49ccfb from careplans.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from careplans.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from careplans.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from careplans.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from careplans.csv
# Added data for patient b24e154c-14c4-8372-2b52-a466bc9b44fe from careplans.csv
# Added data for patient b24e154c-14c4-8372-2b52-a466bc9b44fe from careplans.csv
# Added data for patient b24e154c-14c4-8372-2b52-a466bc9b44fe from careplans.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from careplans.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from careplans.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from careplans.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from careplans.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from careplans.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from careplans.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from careplans.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from careplans.csv
# Added data for patient fd263d8e-7d79-e54c-0c5f-351a1e3635ed from careplans.csv
# Added data for patient fd263d8e-7d79-e54c-0c5f-351a1e3635ed from careplans.csv
# Added data for patient fd263d8e-7d79-e54c-0c5f-351a1e3635ed from careplans.csv
# Added data for patient fd263d8e-7d79-e54c-0c5f-351a1e3635ed from careplans.csv
# Checking file: drive/MyDrive/NCPDP/csv/providers.csv
# Reading file: drive/MyDrive/NCPDP/csv/providers.csv
# Checking file: drive/MyDrive/NCPDP/csv/allergies.csv
# Reading file: drive/MyDrive/NCPDP/csv/allergies.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from allergies.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from allergies.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from allergies.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from allergies.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from allergies.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from allergies.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from allergies.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from allergies.csv
# Added data for patient 021b10fa-cb4a-6830-4891-66b4d91b46b1 from allergies.csv
# Added data for patient bdbe1585-a264-dc8c-dcf9-472b0280a91d from allergies.csv
# Added data for patient bdbe1585-a264-dc8c-dcf9-472b0280a91d from allergies.csv
# Added data for patient bdbe1585-a264-dc8c-dcf9-472b0280a91d from allergies.csv
# Added data for patient bdbe1585-a264-dc8c-dcf9-472b0280a91d from allergies.csv
# Added data for patient bdbe1585-a264-dc8c-dcf9-472b0280a91d from allergies.csv
# Added data for patient f1443845-26e3-aece-4bb9-685a861e6f6e from allergies.csv
# Added data for patient f1443845-26e3-aece-4bb9-685a861e6f6e from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient f2a89854-062a-f8b2-7d28-ac0dc72dac53 from allergies.csv
# Added data for patient cf5f121e-bf1c-c37b-d279-6a0e5a46228e from allergies.csv
# Added data for patient cf5f121e-bf1c-c37b-d279-6a0e5a46228e from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient b66fd29b-20a6-8ba7-d592-e4b6390d5948 from allergies.csv
# Added data for patient 8bce03af-b805-fcfa-7916-4e2c792e0614 from allergies.csv
# Added data for patient cd715af6-e350-7eb4-a9b7-2f07846f2f32 from allergies.csv
# Added data for patient e3ba01fe-2737-d5d1-0d63-dff4a4aa76bf from allergies.csv
# Added data for patient e3ba01fe-2737-d5d1-0d63-dff4a4aa76bf from allergies.csv
# Added data for patient 8263ba63-4afc-95c6-f1d2-9b3d367a1168 from allergies.csv
# Added data for patient 8863dbc1-d59a-d7cb-43fc-9003c6f45da9 from allergies.csv
# Added data for patient 434de273-7ff6-bd0a-d0f8-3c06fff5effc from allergies.csv
# Added data for patient ea3a859d-a605-a7dd-5a49-6da98c14b5be from allergies.csv
# Added data for patient ea3a859d-a605-a7dd-5a49-6da98c14b5be from allergies.csv
# Added data for patient ea3a859d-a605-a7dd-5a49-6da98c14b5be from allergies.csv
# Added data for patient ea3a859d-a605-a7dd-5a49-6da98c14b5be from allergies.csv
# Added data for patient ea3a859d-a605-a7dd-5a49-6da98c14b5be from allergies.csv
# Added data for patient ea3a859d-a605-a7dd-5a49-6da98c14b5be from allergies.csv
# Added data for patient bc7aa58d-0b6a-34ee-cdd1-c9be34fa36f1 from allergies.csv
# Added data for patient 02827a83-1ee1-3b14-8f9a-7faea904bd73 from allergies.csv
# Added data for patient 778344f3-f13a-12c5-7eea-a7465f4447b6 from allergies.csv
# Added data for patient 778344f3-f13a-12c5-7eea-a7465f4447b6 from allergies.csv
# Checking file: drive/MyDrive/NCPDP/csv/procedures.csv
# Reading file: drive/MyDrive/NCPDP/csv/procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from procedures.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from procedures.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from procedures.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from procedures.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from procedures.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from procedures.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from procedures.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from procedures.csv
# Checking file: drive/MyDrive/NCPDP/csv/observations.csv
# Reading file: drive/MyDrive/NCPDP/csv/observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from observations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from observations.csv
# Checking file: drive/MyDrive/NCPDP/csv/medications.csv
# Reading file: drive/MyDrive/NCPDP/csv/medications.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from medications.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from medications.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from medications.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from medications.csv
# Checking file: drive/MyDrive/NCPDP/csv/payers.csv
# Reading file: drive/MyDrive/NCPDP/csv/payers.csv
# Checking file: drive/MyDrive/NCPDP/csv/supplies.csv
# Reading file: drive/MyDrive/NCPDP/csv/supplies.csv
# Checking file: drive/MyDrive/NCPDP/csv/conditions.csv
# Reading file: drive/MyDrive/NCPDP/csv/conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from conditions.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from conditions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from conditions.csv
# Checking file: drive/MyDrive/NCPDP/csv/devices.csv
# Reading file: drive/MyDrive/NCPDP/csv/devices.csv
# Added data for patient 6f4d77e9-2203-03a3-8966-92a22a21000a from devices.csv
# Added data for patient a58de3fd-f026-902b-55c1-872dc042e0c5 from devices.csv
# Added data for patient 8ae88d45-4998-cf3b-6cf4-2d1f9d1324c6 from devices.csv
# Added data for patient 6d1f2671-e6a0-a415-5373-3a2bda361932 from devices.csv
# Added data for patient 62d625d2-f8fa-2f32-0ea0-5dc36f0a9a3f from devices.csv
# Added data for patient 8bce03af-b805-fcfa-7916-4e2c792e0614 from devices.csv
# Added data for patient 2440c23e-0661-3dd8-8468-aa8631d24495 from devices.csv
# Added data for patient 9a65567d-3888-f9af-379b-0e5b52a6be63 from devices.csv
# Added data for patient 9a65567d-3888-f9af-379b-0e5b52a6be63 from devices.csv
# Added data for patient 84bce711-07a7-1e23-40c6-7ec44431bcb3 from devices.csv
# Added data for patient c6f55546-d0f8-fea0-d392-6d5c6d648d3a from devices.csv
# Added data for patient fec6d99f-1cfd-f397-e740-e3952410ea2a from devices.csv
# Added data for patient 0eb80696-9fc6-16be-c092-5eaf012a004b from devices.csv
# Added data for patient d310dea3-499e-1a27-b6cd-fe706b04a0b7 from devices.csv
# Added data for patient d310dea3-499e-1a27-b6cd-fe706b04a0b7 from devices.csv
# Added data for patient f704507b-6f1a-2cd8-0e23-9ddacfa52339 from devices.csv
# Added data for patient f704507b-6f1a-2cd8-0e23-9ddacfa52339 from devices.csv
# Added data for patient 1e4309a5-6025-d8fe-2f3c-79d95cf41e5d from devices.csv
# Added data for patient 04dac88b-16ba-5dd4-f7de-e72ff0b9a75b from devices.csv
# Added data for patient bff8bb1f-d292-a7d8-32df-85ae78159794 from devices.csv
# Added data for patient ff9f350e-e15b-de19-dada-21e5c1337eb0 from devices.csv
# Added data for patient 2d197019-101a-2067-6151-771a23734945 from devices.csv
# Added data for patient 9cef1eb1-3864-17eb-4aa1-99666b5db2cc from devices.csv
# Added data for patient 05cad767-bd44-89d8-fbc1-a22154e5cb2a from devices.csv
# Added data for patient 5b122628-8b51-6238-55f7-a3c0afa98ca4 from devices.csv
# Added data for patient 76106ee3-8996-8143-efb4-76ec0de33233 from devices.csv
# Added data for patient e6bb3b10-3b52-341c-015f-e7ea9d49bfff from devices.csv
# Added data for patient d5e15e19-d8cc-b2e2-499f-668038e5ddb0 from devices.csv
# Added data for patient 6cc077ec-d7a8-4854-db1f-c2f468cbe4d9 from devices.csv
# Added data for patient 771d4e3e-3e9f-2052-6be5-f622fd424f75 from devices.csv
# Added data for patient da62d992-9d16-390b-c26b-09da6f897852 from devices.csv
# Added data for patient 2e01dec1-eef1-6ea5-5a91-971351968051 from devices.csv
# Added data for patient 9b32f757-de87-aff7-15a0-bc1a681d74ca from devices.csv
# Added data for patient f75f3740-09ad-00aa-ac43-806c2e8eba27 from devices.csv
# Added data for patient 96096072-148f-d5da-8b36-f471210f626c from devices.csv
# Added data for patient eebda2ce-5761-7f57-e5ec-8ffc782e5d7f from devices.csv
# Added data for patient 7b2573a5-6f9f-ffa5-6ab9-100b7e99f4e8 from devices.csv
# Added data for patient 6f140943-c786-56ec-bf56-c62abd3c3f12 from devices.csv
# Added data for patient 8366ea2a-1ef7-dfe3-00e7-fa7136e5a57a from devices.csv
# Added data for patient 6f14c177-f3a2-505f-a6fb-a1ee82171293 from devices.csv
# Added data for patient c03812a9-8d7f-d554-5039-6ec757cc2bea from devices.csv
# Added data for patient 54e5bb5d-073d-7f02-df60-aa94cba5c5ec from devices.csv
# Added data for patient 01541ad3-5323-cb64-96a7-c2ef42941253 from devices.csv
# Added data for patient 9657a386-9cae-a682-354e-7fb613275756 from devices.csv
# Added data for patient 2d4ab7ba-23b9-291d-756b-b22f57a9fafd from devices.csv
# Added data for patient bb76ce29-5abd-31fe-c3a9-045a5eaabf25 from devices.csv
# Added data for patient 9a41c6ca-8481-9747-41c6-3b96551a9477 from devices.csv
# Added data for patient 2e0c4697-1758-643e-f14b-dd9fca468262 from devices.csv
# Added data for patient 7359f186-9e25-5799-0065-09c284efce8a from devices.csv
# Added data for patient dedd5667-b0fe-bf46-2c2a-2dc7f07e57b5 from devices.csv
# Checking file: drive/MyDrive/NCPDP/csv/encounters.csv
# Reading file: drive/MyDrive/NCPDP/csv/encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from encounters.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from encounters.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from encounters.csv
# Checking file: drive/MyDrive/NCPDP/csv/imaging_studies.csv
# Reading file: drive/MyDrive/NCPDP/csv/imaging_studies.csv
# Added data for patient 4fdafa07-e5cb-9b2a-55c6-50902c49ccfb from imaging_studies.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from imaging_studies.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from imaging_studies.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from imaging_studies.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient e4c173c1-99ab-865e-4094-970fd1ac8df8 from imaging_studies.csv
# Added data for patient a58de3fd-f026-902b-55c1-872dc042e0c5 from imaging_studies.csv
# Added data for patient a58de3fd-f026-902b-55c1-872dc042e0c5 from imaging_studies.csv
# Added data for patient a58de3fd-f026-902b-55c1-872dc042e0c5 from imaging_studies.csv
# Added data for patient b6d9f9f6-b4b0-8b31-1827-dcc141011135 from imaging_studies.csv
# Added data for patient b6d9f9f6-b4b0-8b31-1827-dcc141011135 from imaging_studies.csv
# Added data for patient b6d9f9f6-b4b0-8b31-1827-dcc141011135 from imaging_studies.csv
# Added data for patient 7696f89d-e2f0-308a-e66a-58eafbc08b63 from imaging_studies.csv
# Added data for patient e1244be8-cdbe-a5ae-f401-b462cdb389cb from imaging_studies.csv
# Added data for patient e1244be8-cdbe-a5ae-f401-b462cdb389cb from imaging_studies.csv
# Added data for patient e1244be8-cdbe-a5ae-f401-b462cdb389cb from imaging_studies.csv
# Added data for patient e1244be8-cdbe-a5ae-f401-b462cdb389cb from imaging_studies.csv
# Added data for patient e015f011-4286-caa1-01eb-81feec52e20d from imaging_studies.csv
# Added data for patient 75425ac1-ff8b-76eb-5b4b-633b619c87c3 from imaging_studies.csv
# Added data for patient 0c187b1f-27d8-a277-54ba-a2b7ee0db45e from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Added data for patient 6a2ed053-e2fc-ccd3-88b3-abedd7808593 from imaging_studies.csv
# Checking file: drive/MyDrive/NCPDP/csv/immunizations.csv
# Reading file: drive/MyDrive/NCPDP/csv/immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from immunizations.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from immunizations.csv
# Checking file: drive/MyDrive/NCPDP/csv/organizations.csv
# Reading file: drive/MyDrive/NCPDP/csv/organizations.csv
# Checking file: drive/MyDrive/NCPDP/csv/payer_transitions.csv
# Reading file: drive/MyDrive/NCPDP/csv/payer_transitions.csv
# Added data for patient b8eb8d31-1031-fb5b-e207-b9815f80744c from payer_transitions.csv
# Added data for patient 8b0484cd-3dbd-8b8d-1b72-a32f74a5a846 from payer_transitions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from payer_transitions.csv
# Added data for patient ce9bd436-6b59-0452-86a4-61f3642736bc from payer_transitions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from payer_transitions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from payer_transitions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from payer_transitions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from payer_transitions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from payer_transitions.csv
# Added data for patient 6fc3e360-ae68-c411-e091-4734df51eb18 from payer_transitions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from payer_transitions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from payer_transitions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from payer_transitions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from payer_transitions.csv
# Added data for patient ce4ce4d8-d4e2-aca2-5a92-8ce703c5077a from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient b4c809c0-de80-1c62-ab58-7b885e475e76 from payer_transitions.csv
# Added data for patient 4fdafa07-e5cb-9b2a-55c6-50902c49ccfb from payer_transitions.csv
# Added data for patient 4fdafa07-e5cb-9b2a-55c6-50902c49ccfb from payer_transitions.csv
# Added data for patient 69e46a15-edee-8a95-fc7b-f16e72e0aabf from payer_transitions.csv
# Added data for patient b24e154c-14c4-8372-2b52-a466bc9b44fe from payer_transitions.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from payer_transitions.csv
# Added data for patient a4840112-31e6-b8a8-296f-7a4b89bee4f7 from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 46d26ec0-3ca8-dd40-2b29-c06b8f5bc5fd from payer_transitions.csv
# Added data for patient 9c452d24-00b0-d58f-4cd5-b82bd6695646 from payer_transitions.csv
# Total patients: 3539
# Successfully converted data from multiple CSV files to nested JSON.

# %%
# @title Default title text
import csv
import json
import os

def csv_to_json_nested(csv_dir, json_filepath):  # Removed limit parameter
    patient_data = {}  # Dictionary to store patient data

    csv_files = ['patients.csv', 'careplans.csv',
                 'providers.csv', 'allergies.csv',
                 'procedures.csv', 'observations.csv',
                 'medications.csv','payers.csv',
                 'supplies.csv','conditions.csv',
                 'devices.csv','encounters.csv',
                 'imaging_studies.csv','immunizations.csv',
                 'organizations.csv','payer_transitions.csv']  # Add your CSV file names here

    # Process patients.csv first to create the root structure
    patients_filepath = os.path.join(csv_dir, 'patients.csv')
    try:
        with open(patients_filepath, 'r', encoding='utf-8') as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                patient_id = row.get('Id')  # Get patient ID from 'id' column
                if patient_id:
                    patient_data[patient_id] = {'patient_details': row}  # Store patient details as root
    except FileNotFoundError:
        print(f"File not found: {patients_filepath}")
        return
    except Exception as e:
        print(f"An error occurred while reading {patients_filepath}: {e}")
        return

    # Process other CSV files and nest data under patient IDs
    for filename in csv_files[1:]:  # Skip patients.csv (already processed)
        csv_filepath = os.path.join(csv_dir, filename)
        print(f"Checking file: {csv_filepath}")

        try:
            with open(csv_filepath, 'r', encoding='utf-8') as csvfile:
                reader = csv.DictReader(csvfile)
                print(f"Reading file: {csv_filepath}")

                for row in reader:  # Removed count and limit check
                    patient_id = row.get('PATIENT')  # Get patient ID from 'PATIENT' column
                    if patient_id and patient_id in patient_data:
                        # Use filename as key for nested data
                        if filename[:-4] not in patient_data[patient_id]:
                            patient_data[patient_id][filename[:-4]] = []
                        patient_data[patient_id][filename[:-4]].append(row)

                        print(f"Added data for patient {patient_id} from {filename}")

        except FileNotFoundError:
            print(f"File not found: {csv_filepath}")
            continue
        except Exception as e:
            print(f"An error occurred while reading {csv_filepath}: {e}")
            return

    print(f"Total patients: {len(patient_data)}")

    try:
        with open(json_filepath, 'w', encoding='utf-8') as jsonfile:
            json.dump(patient_data, jsonfile, indent=4)
        print(f"Successfully converted data from multiple CSV files to nested JSON.")
    except Exception as e:
        print(f"An error occurred while writing to JSON file: {e}")

# Example usage:
csv_dir = 'drive/MyDrive/NCPDP/csv'  # Directory containing CSV files
json_filepath = 'output.json'
csv_to_json_nested(csv_dir, json_filepath)
# Out:
# Streaming output truncated to the last 5000 lines.
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# Added data for patient 19ac1829-945a-c4a3-63fb-ce50c89977ca from medications.csv
# ...
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 14ffb3e7-511d-46d5-dbb4-edef8cd15fe6 from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# Added data for patient 404175bd-6673-43bb-2e35-9644e400809b from medications.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-4f6c07976ae1> in <cell line: 0>()
#      70 csv_dir = 'csv'  # Directory containing CSV files
#      71 json_filepath = 'output.json'
# ---> 72 csv_to_json_nested(csv_dir, json_filepath)
#
# <ipython-input-26-4f6c07976ae1> in csv_to_json_nested(csv_dir, json_filepath)
#      41                 print(f"Reading file: {csv_filepath}")
#      42
# ---> 43                 for row in reader:  # Removed count and limit check
#      44                     patient_id = row.get('PATIENT')  # Get patient ID from 'PATIENT' column
#      45                     if patient_id and patient_id in patient_data:
#
# /usr/lib/python3.11/csv.py in __next__(self)
#     109             # Used only for its side effect.
#     110             self.fieldnames
# --> 111         row = next(self.reader)
#     112         self.line_num = self.reader.line_num
#     113
#
# KeyboardInterrupt:
